# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import os
os.environ['OMP_NUM_THREADS'] = "128"
os.environ['KMP_AFFINITY'] = "granularity=fine,compact,1,0"
os.environ['KMP_BLOCKTIME'] = "0"
#os.environ['TORCH_USE_CUDA_DSA'] = "1"
#os.environ['TORCHDYNAMO_REPRO_AFTER'] ="aot" 
#os.environ['TORCHDYNAMO_REPRO_LEVEL'] = "4"

# %%
import time
import logging
import numpy as np
import torch
import torch.nn as nn
import torch._dynamo
import torch._inductor
from torchvision import datasets
from torchvision import transforms
from torchvision import models
from torch.utils.data.sampler import SubsetRandomSampler
from torch.profiler import profile, record_function, ProfilerActivity

# %%
#torch.backends.cuda.matmul.allow_tf32 = True
#torch._dynamo.config.cache_size_limit = 2

# %%
def build_data_loader(data_dir, batch_size, random_seed=42, valid_size=0.1, shuffle=True, test=False):

    transform = transforms.Compose([transforms.ToTensor()])
    transform.crop_size=224
    transform.resize_size=224
    
    train_dataset = datasets.CIFAR10(root=data_dir, train=True, download=True, transform=transform)
    test_dataset = datasets.CIFAR10(root=data_dir, train=False, download=True, transform=transform)

    train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size)
    test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=shuffle)

    return (train_loader, test_loader)

# %%
def train(model, data_loader, num_epochs, criterion, optimizer, device):
    total_steps = len(train_loader)
    epoch_time = []
    for epoch in range(num_epochs):
        start = time.time()
        for step, (images, labels) in enumerate(train_loader):  
            # Move tensors to the configured device
            images = images.to(device)
            labels = labels.to(device)
        
            # Forward pass
            outputs = model(images)
            outputs.to(device)
            loss = criterion(outputs, labels)
        
            # Backward and optimize
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            #print ('Step [{}/{}], Loss: {:.4f}'.format(step+1, total_steps, loss.item()))
        end = time.time()
        elapsed_time = int(end - start)
        epoch_time.append(elapsed_time)
               
        print ('Epoch [{}/{}], Loss: {:.4f}, time: {} seconds'.format(epoch+1, num_epochs, loss.item(), elapsed_time))
    return epoch_time

# %%
def test(model, test_loader, device):
    with torch.no_grad():
        correct = 0
        total = 0
        for images, labels in test_loader:
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            del images, labels, outputs

    accuracy = 100 * (correct / total)
    print('Accuracy of the network on the {} test images: {} %'.format(10000, accuracy))
    return accuracy

# %%
import torch
import warnings

gpu_ok = False
if torch.cuda.is_available():
    device_cap = torch.cuda.get_device_capability()
    if device_cap in ((7, 0), (8, 0), (9, 0)):
        gpu_ok = True

if not gpu_ok:
    warnings.warn("GPU is not NVIDIA V100, A100, or H100. Speedup numbers may be lower than expected.")

# %%
# General parameters
data_dir = '/tmp'
device = "cuda"

# Hyperparameters
lr = 0.00001
weight_decay = 0.005
batch_size = 64
num_epochs = 50
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam

# FashionMNIST dataset 
train_loader, test_loader = build_data_loader(data_dir=data_dir, batch_size=batch_size)

# Model
weights = models.DenseNet121_Weights.DEFAULT
net = models.densenet121(weights=weights)
#net = net.train()
net = net.to(device)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
#backends = torch._dynamo.list_backends()
backends = ['aot_ts_nvfuser', 'cudagraphs', 'inductor']
results = []
for backend in backends:
    #del compiled_model
    torch._dynamo.reset()
    print('Compiling model with backend {}'.format(backend))
    mode = None
    if backend == "inductor":
        mode = "reduce-overhead"
    model = torch.compile(net, backend=backend, mode=mode)
    opt = optimizer(model.parameters(), lr, weight_decay=weight_decay)
    start = time.time()
    epoch_time = train(model, train_loader, num_epochs, criterion, opt, device)
    end = time.time()
    training_time = int(end-start)
    print('Training time of {}: {} seconds'.format(backend, training_time))
    accuracy = test(model, test_loader, device)
    result = [backend, training_time, epoch_time, accuracy]
    results.append(result)
# Out:
# Compiling model with backend aot_ts_nvfuser
# Epoch [1/50], Loss: 2.2836, time: 142 seconds
# Epoch [2/50], Loss: 1.7009, time: 108 seconds
# Epoch [3/50], Loss: 0.9180, time: 46 seconds
# Epoch [4/50], Loss: 0.4004, time: 46 seconds
# Epoch [5/50], Loss: 0.2509, time: 46 seconds
# Epoch [6/50], Loss: 0.1606, time: 46 seconds
# Epoch [7/50], Loss: 0.0944, time: 46 seconds
# Epoch [8/50], Loss: 0.0646, time: 45 seconds
# Epoch [9/50], Loss: 0.0440, time: 46 seconds
# Epoch [10/50], Loss: 0.0290, time: 46 seconds
# Epoch [11/50], Loss: 0.0202, time: 46 seconds
# Epoch [12/50], Loss: 0.0129, time: 46 seconds
# Epoch [13/50], Loss: 0.0120, time: 46 seconds
# Epoch [14/50], Loss: 0.0135, time: 46 seconds
# Epoch [15/50], Loss: 0.0062, time: 46 seconds
# Epoch [16/50], Loss: 0.0040, time: 46 seconds
# Epoch [17/50], Loss: 0.0035, time: 46 seconds
# Epoch [18/50], Loss: 0.0044, time: 46 seconds
# Epoch [19/50], Loss: 0.0069, time: 46 seconds
# Epoch [20/50], Loss: 0.0038, time: 46 seconds
# Epoch [21/50], Loss: 0.0040, time: 46 seconds
# Epoch [22/50], Loss: 0.0037, time: 46 seconds
# Epoch [23/50], Loss: 0.0050, time: 46 seconds
# Epoch [24/50], Loss: 0.0051, time: 46 seconds
# Epoch [25/50], Loss: 0.0014, time: 46 seconds
# Epoch [26/50], Loss: 0.0056, time: 46 seconds
# Epoch [27/50], Loss: 0.0036, time: 46 seconds
# Epoch [28/50], Loss: 0.0020, time: 46 seconds
# Epoch [29/50], Loss: 0.0013, time: 46 seconds
# Epoch [30/50], Loss: 0.0014, time: 46 seconds
# Epoch [31/50], Loss: 0.0093, time: 46 seconds
# Epoch [32/50], Loss: 0.0025, time: 46 seconds
# Epoch [33/50], Loss: 0.0025, time: 46 seconds
# Epoch [34/50], Loss: 0.0012, time: 46 seconds
# Epoch [35/50], Loss: 0.0621, time: 46 seconds
# Epoch [36/50], Loss: 0.4585, time: 46 seconds
# Epoch [37/50], Loss: 0.0082, time: 46 seconds
# Epoch [38/50], Loss: 0.0019, time: 46 seconds
# Epoch [39/50], Loss: 0.0016, time: 46 seconds
# Epoch [40/50], Loss: 0.0016, time: 46 seconds
# Epoch [41/50], Loss: 0.0017, time: 46 seconds
# Epoch [42/50], Loss: 0.0152, time: 46 seconds
# Epoch [43/50], Loss: 0.0230, time: 46 seconds
# Epoch [44/50], Loss: 0.0040, time: 46 seconds
# Epoch [45/50], Loss: 0.0017, time: 46 seconds
# Epoch [46/50], Loss: 0.0032, time: 46 seconds
# Epoch [47/50], Loss: 0.0138, time: 46 seconds
# Epoch [48/50], Loss: 0.0110, time: 46 seconds
# Epoch [49/50], Loss: 0.0027, time: 46 seconds
# Epoch [50/50], Loss: 0.0028, time: 46 seconds
# Training time of aot_ts_nvfuser: 2474 seconds
# Accuracy of the network on the 10000 test images: 74.68 %
# Compiling model with backend cudagraphs
# Epoch [1/50], Loss: 0.0096, time: 86 seconds
# Epoch [2/50], Loss: 0.0025, time: 45 seconds
# Epoch [3/50], Loss: 0.0038, time: 44 seconds
# Epoch [4/50], Loss: 0.0048, time: 45 seconds
# Epoch [5/50], Loss: 0.0043, time: 45 seconds
# Epoch [6/50], Loss: 0.0022, time: 45 seconds
# Epoch [7/50], Loss: 0.0026, time: 45 seconds
# Epoch [8/50], Loss: 0.0024, time: 45 seconds
# Epoch [9/50], Loss: 0.0024, time: 45 seconds
# Epoch [10/50], Loss: 0.0098, time: 45 seconds
# Epoch [11/50], Loss: 0.0069, time: 44 seconds
# Epoch [12/50], Loss: 0.0063, time: 44 seconds
# Epoch [13/50], Loss: 0.0039, time: 44 seconds
# Epoch [14/50], Loss: 0.0031, time: 44 seconds
# Epoch [15/50], Loss: 0.0028, time: 44 seconds
# Epoch [16/50], Loss: 0.0030, time: 44 seconds
# Epoch [17/50], Loss: 0.0034, time: 45 seconds
# Epoch [18/50], Loss: 0.0037, time: 45 seconds
# Epoch [19/50], Loss: 0.0196, time: 45 seconds
# Epoch [20/50], Loss: 0.0214, time: 45 seconds
# Epoch [21/50], Loss: 0.0040, time: 45 seconds
# Epoch [22/50], Loss: 0.0035, time: 45 seconds
# Epoch [23/50], Loss: 0.0037, time: 45 seconds
# Epoch [24/50], Loss: 0.0039, time: 44 seconds
# Epoch [25/50], Loss: 0.0042, time: 45 seconds
# Epoch [26/50], Loss: 0.0047, time: 45 seconds
# Epoch [27/50], Loss: 0.0139, time: 45 seconds
# Epoch [28/50], Loss: 0.0075, time: 45 seconds
# Epoch [29/50], Loss: 0.0062, time: 45 seconds
# Epoch [30/50], Loss: 0.0055, time: 45 seconds
# Epoch [31/50], Loss: 0.0044, time: 45 seconds
# Epoch [32/50], Loss: 0.0046, time: 45 seconds
# Epoch [33/50], Loss: 0.0049, time: 45 seconds
# Epoch [34/50], Loss: 0.0054, time: 45 seconds
# Epoch [35/50], Loss: 0.2759, time: 45 seconds
# Epoch [36/50], Loss: 0.2668, time: 45 seconds
# Epoch [37/50], Loss: 0.0832, time: 44 seconds
# Epoch [38/50], Loss: 0.1024, time: 44 seconds
# Epoch [39/50], Loss: 0.0303, time: 44 seconds
# Epoch [40/50], Loss: 0.0167, time: 44 seconds
# Epoch [41/50], Loss: 0.0134, time: 45 seconds
# Epoch [42/50], Loss: 0.0081, time: 45 seconds
# Epoch [43/50], Loss: 0.0072, time: 45 seconds
# Epoch [44/50], Loss: 0.0070, time: 44 seconds
# Epoch [45/50], Loss: 0.0088, time: 44 seconds
# Epoch [46/50], Loss: 0.0095, time: 44 seconds
# Epoch [47/50], Loss: 0.0080, time: 44 seconds
# Epoch [48/50], Loss: 0.0074, time: 44 seconds
# Epoch [49/50], Loss: 0.0071, time: 44 seconds
# Epoch [50/50], Loss: 0.0078, time: 44 seconds
# Training time of cudagraphs: 2290 seconds
# Accuracy of the network on the 10000 test images: 77.57 %
# Compiling model with backend inductor
# Epoch [1/50], Loss: 0.0088, time: 140 seconds
# Epoch [2/50], Loss: 0.0099, time: 28 seconds
# Epoch [3/50], Loss: 0.0066, time: 26 seconds
# Epoch [4/50], Loss: 0.0080, time: 26 seconds
# Epoch [5/50], Loss: 0.0077, time: 25 seconds
# Epoch [6/50], Loss: 0.0089, time: 25 seconds
# Epoch [7/50], Loss: 0.0130, time: 26 seconds
# Epoch [8/50], Loss: 0.0095, time: 25 seconds
# Epoch [9/50], Loss: 0.0092, time: 26 seconds
# Epoch [10/50], Loss: 0.0077, time: 25 seconds
# Epoch [11/50], Loss: 0.0072, time: 26 seconds
# Epoch [12/50], Loss: 0.0076, time: 25 seconds
# Epoch [13/50], Loss: 0.0086, time: 26 seconds
# Epoch [14/50], Loss: 0.0083, time: 25 seconds
# Epoch [15/50], Loss: 0.0112, time: 26 seconds
# Epoch [16/50], Loss: 0.0089, time: 25 seconds
# Epoch [17/50], Loss: 0.0087, time: 26 seconds
# Epoch [18/50], Loss: 0.0092, time: 25 seconds
# Epoch [19/50], Loss: 0.0140, time: 25 seconds
# Epoch [20/50], Loss: 0.0116, time: 26 seconds
# Epoch [21/50], Loss: 0.0162, time: 26 seconds
# Epoch [22/50], Loss: 0.0097, time: 25 seconds
# Epoch [23/50], Loss: 0.0102, time: 25 seconds
# Epoch [24/50], Loss: 0.0115, time: 26 seconds
# Epoch [25/50], Loss: 0.0341, time: 26 seconds
# Epoch [26/50], Loss: 0.0458, time: 25 seconds
# Epoch [27/50], Loss: 0.0287, time: 25 seconds
# Epoch [28/50], Loss: 0.0486, time: 26 seconds
# Epoch [29/50], Loss: 0.1590, time: 25 seconds
# Epoch [30/50], Loss: 0.1744, time: 26 seconds
# Epoch [31/50], Loss: 0.3122, time: 25 seconds
# Epoch [32/50], Loss: 0.0487, time: 26 seconds
# Epoch [33/50], Loss: 0.1135, time: 25 seconds
# Epoch [34/50], Loss: 0.2332, time: 25 seconds
# Epoch [35/50], Loss: 0.2338, time: 25 seconds
# Epoch [36/50], Loss: 0.0175, time: 25 seconds
# Epoch [37/50], Loss: 0.0124, time: 25 seconds
# Epoch [38/50], Loss: 0.0151, time: 25 seconds
# Epoch [39/50], Loss: 0.0179, time: 25 seconds
# Epoch [40/50], Loss: 0.0131, time: 25 seconds
# Epoch [41/50], Loss: 0.0125, time: 25 seconds
# Epoch [42/50], Loss: 0.0126, time: 25 seconds
# Epoch [43/50], Loss: 0.0126, time: 25 seconds
# Epoch [44/50], Loss: 0.0127, time: 25 seconds
# Epoch [45/50], Loss: 0.0127, time: 25 seconds
# Epoch [46/50], Loss: 0.0128, time: 25 seconds
# Epoch [47/50], Loss: 0.0126, time: 25 seconds
# Epoch [48/50], Loss: 0.0277, time: 25 seconds
# Epoch [49/50], Loss: 0.0146, time: 25 seconds
# Epoch [50/50], Loss: 0.0129, time: 25 seconds
# Training time of inductor: 1407 seconds
# skipping cudagraphs due to input mutation
# skipping cudagraphs due to input mutation
# Accuracy of the network on the 10000 test images: 79.9 %

# %%
results
# Out:
# [['aot_ts_nvfuser',
#   2474,
#   [142,
#    108,
#    46,
#    46,
#    46,
#    46,
#    46,
#    45,
#    46,
#    46,
#    46,
#    46,
#    46,
#    46,
#    46,
#    46,
#    46,
#    46,
#    46,
#    46,
#    46,
#    46,
#    46,
#    46,
#    46,
#    46,
#    46,
#    46,
#    46,
#    46,
#    46,
#    46,
#    46,
#    46,
#    46,
#    46,
#    46,
#    46,
#    46,
#    46,
#    46,
#    46,
#    46,
#    46,
#    46,
#    46,
#    46,
#    46,
#    46,
#    46],
#   74.68],
#  ['cudagraphs',
#   2290,
#   [86,
#    45,
#    44,
#    45,
#    45,
#    45,
#    45,
#    45,
#    45,
#    45,
#    44,
#    44,
#    44,
#    44,
#    44,
#    44,
#    45,
#    45,
#    45,
#    45,
#    45,
#    45,
#    45,
#    44,
#    45,
#    45,
#    45,
#    45,
#    45,
#    45,
#    45,
#    45,
#    45,
#    45,
#    45,
#    45,
#    44,
#    44,
#    44,
#    44,
#    45,
#    45,
#    45,
#    44,
#    44,
#    44,
#    44,
#    44,
#    44,
#    44],
#   77.57],
#  ['inductor',
#   1407,
#   [140,
#    28,
#    26,
#    26,
#    25,
#    25,
#    26,
#    25,
#    26,
#    25,
#    26,
#    25,
#    26,
#    25,
#    26,
#    25,
#    26,
#    25,
#    25,
#    26,
#    26,
#    25,
#    25,
#    26,
#    26,
#    25,
#    25,
#    26,
#    25,
#    26,
#    25,
#    26,
#    25,
#    25,
#    25,
#    25,
#    25,
#    25,
#    25,
#    25,
#    25,
#    25,
#    25,
#    25,
#    25,
#    25,
#    25,
#    25,
#    25,
#    25],
#   79.9]]

# %%
torch._dynamo.list_backends()
# Out:
# ['aot_ts_nvfuser',
#  'cudagraphs',
#  'inductor',
#  'ipex',
#  'nvprims_nvfuser',
#  'onnxrt',
#  'tvm']
